# %%
# TRYING TO MAKE CALIBRATIONS WORK FROM SCRATCH

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
# path_to_file = '/home/simeonoa/robot_cable_insertion/ur5/calibration/cam_cal_12_05_23_final.csv'
path_to_file = "/home/gasket/robot_cable_insertion/ur5/calibration/cam_cal_2_20_24_final.csv"
df = pd.read_csv(path_to_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # path_to_file = '/home/simeonoa/robot_cable_insertion/ur5/calibration/cam_cal_12_05_23_final.csv'
#       2 path_to_file = "/home/simeonoa/robot_cable_insertion/ur5/calibration/cam_cal_02_20_24_final.csv"
# ----> 3 df = pd.read_csv(path_to_file)
#
# File ~/miniconda3/envs/gasket2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/gasket2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File ~/miniconda3/envs/gasket2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/gasket2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File ~/miniconda3/envs/gasket2/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/simeonoa/robot_cable_insertion/ur5/calibration/cam_cal_02_20_24_final.csv'

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#    real_x  real_y  im_x  im_y
# 0  381.00 -479.85   120   233
# 1  347.65 -220.54    98   579
# 2  374.60   77.87   112   975
# 3  378.33  226.75   113  1171
# 4  358.75  424.45    91  1424

# %%
print(df.corr())
# Out:
#           real_x    real_y      im_x      im_y
# real_x  1.000000 -0.060246  0.998182 -0.051725
# real_y -0.060246  1.000000 -0.104818  0.999855
# im_x    0.998182 -0.104818  1.000000 -0.096211
# im_y   -0.051725  0.999855 -0.096211  1.000000

# %%
X_in = df['im_x'].values.reshape(-1, 1)
X_out = df['real_x'].values.reshape(-1, 1)
Y_in = df['im_y'].values.reshape(-1, 1)
Y_out = df['real_y'].values.reshape(-1, 1)

# %%
im_coords = np.column_stack((X_in, Y_in))
print(im_coords.shape)
model_x = LinearRegression()
model_y = LinearRegression()
model_x.fit(im_coords, X_out)
model_y.fit(im_coords, Y_out)
# Out:
# (22, 2)
# LinearRegression()

# %%
new_im_coords = np.array([[269.4, 184]])
pred_real_x = model_x.predict(new_im_coords)
pred_real_y = model_y.predict(new_im_coords)
print(pred_real_x, pred_real_y)
# Out:
# [[479.48070885]] [[-520.79099323]]

# %%
X_in_train, X_in_test, X_out_train, X_out_test = train_test_split(X_in, X_out, test_size = 0.2)
Y_in_train, Y_in_test, Y_out_train, Y_out_test = train_test_split(Y_in, Y_out, test_size = 0.2)

# %%
X_result = regressor.fit(X_in_train, X_out_train)
Y_result = regressor.fit(Y_in_train, Y_out_train)
X_what = X_result

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [-662.16350223]
# [[0.75480835]]

# %%
print(X_what.intercept_[0])
print(X_what.coef_[0][0])
print(Y_result.intercept_[0])
print(Y_result.coef_[0][0])
# Out:
# -662.1635022263797
# 0.7548083546285791
# -662.1635022263797
# 0.7548083546285791

# %%
Y_diffs = Y_out - (Y_result.intercept_[0] + Y_result.coef_[0][0] * Y_in)
y_est = Y_result.intercept_[0] + Y_result.coef_[0][0] * 184
x_est = X_result.intercept_[0] + X_result.coef_[0][0] * 269.4

# %%
print(Y_diffs)
print(x_est, y_est)
# Out:
# [[  6.4431556 ]
#  [  4.5894649 ]
#  [  4.09535646]
#  [  5.03291896]
#  [ 11.76640524]
#  [ -1.20102394]
#  [  4.39141801]
#  [  4.80762399]
#  [ -2.44743656]
#  [ -1.68422803]
#  [ -3.78927747]
#  [  2.15768621]
#  [ -2.51586451]
#  [ -0.53035624]
#  [  0.06581308]
#  [ -3.88858643]
#  [-10.09812759]
#  [  2.90901717]
#  [ -5.12934413]
#  [  9.02291229]
#  [  0.74716515]
#  [ -7.58150833]]
# -458.8181314894405 -523.2787649747212
