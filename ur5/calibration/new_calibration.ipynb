# %%
# TRYING TO MAKE CALIBRATIONS WORK FROM SCRATCH

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
# Out:
# /tmp/ipykernel_1154354/3545228743.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# path_to_file = '/home/simeonoa/robot_cable_insertion/ur5/calibration/cam_cal_12_05_23_final.csv'
path_to_file = "/home/simeonoa/robot_cable_insertion/ur5/calibration/cam_cal_02_15_24_final.csv"
df = pd.read_csv(path_to_file)

# %%
print(df)
# Out:
#     real_x  real_y  im_x  im_y
# 0   381.00 -479.85   120   233
# 1   347.65 -220.54    98   579
# 2   374.60   77.87   112   975
# 3   378.33  226.75   113  1171
# 4   358.75  424.45    91  1424
# 5   458.23 -326.72   239   446
# 6   441.83  -35.81   213   824
# 7   464.28  343.52   224  1326
# 8   563.60 -471.38   383   256
# 9   519.97 -182.28   317   638
# 10  500.17   91.12   282  1003
# 11  608.58 -387.52   429   361
# 12  641.24  -71.40   473   786
# 13  604.98  227.98   405  1180
# 14  593.81  430.11   395  1447
# 15  703.46 -477.35   557   250
# 16  720.50   89.34   555  1009
# 17  765.02  288.03   599  1255
# 18  788.79  384.91   634  1394
# 19  820.40 -419.15   710   310
# 20  794.64 -233.44   658   567
# 21  796.26   -0.23   678   887

# %%
df.head()
# Out:
#    real_x  real_y  im_x  im_y
# 0  381.00 -479.85   120   233
# 1  347.65 -220.54    98   579
# 2  374.60   77.87   112   975
# 3  378.33  226.75   113  1171
# 4  358.75  424.45    91  1424

# %%
print(df.corr())
# Out:
#           real_x    real_y      im_x      im_y
# real_x  1.000000 -0.060246  0.998182 -0.051725
# real_y -0.060246  1.000000 -0.104818  0.999855
# im_x    0.998182 -0.104818  1.000000 -0.096211
# im_y   -0.051725  0.999855 -0.096211  1.000000

# %%
X_in = df['im_x'].values.reshape(-1, 1)
X_out = df['real_x'].values.reshape(-1, 1)
Y_in = df['im_y'].values.reshape(-1, 1)
Y_out = df['real_y'].values.reshape(-1, 1)

# %%
im_coords = np.column_stack((X_in, Y_in))
print(im_coords.shape)
model_x = LinearRegression()
model_y = LinearRegression()
model_x.fit(im_coords, X_out)
model_y.fit(im_coords, Y_out)
# Out:
# (22, 2)
# LinearRegression()

# %%
new_im_coords = np.array([[269.4, 184]])
pred_real_x = model_x.predict(new_im_coords)
pred_real_y = model_y.predict(new_im_coords)
print(pred_real_x, pred_real_y)
# Out:
# [[479.48070885]] [[-520.79099323]]

# %%
X_in_train, X_in_test, X_out_train, X_out_test = train_test_split(X_in, X_out, test_size = 0.2)
Y_in_train, Y_in_test, Y_out_train, Y_out_test = train_test_split(Y_in, Y_out, test_size = 0.2)

# %%
X_result = regressor.fit(X_in_train, X_out_train)
Y_result = regressor.fit(Y_in_train, Y_out_train)
X_what = X_result

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [-662.16350223]
# [[0.75480835]]

# %%
print(X_what.intercept_[0])
print(X_what.coef_[0][0])
print(Y_result.intercept_[0])
print(Y_result.coef_[0][0])
# Out:
# -662.1635022263797
# 0.7548083546285791
# -662.1635022263797
# 0.7548083546285791

# %%
Y_diffs = Y_out - (Y_result.intercept_[0] + Y_result.coef_[0][0] * Y_in)
y_est = Y_result.intercept_[0] + Y_result.coef_[0][0] * 184
x_est = X_result.intercept_[0] + X_result.coef_[0][0] * 269.4

# %%
print(Y_diffs)
print(x_est, y_est)
# Out:
# [[  6.4431556 ]
#  [  4.5894649 ]
#  [  4.09535646]
#  [  5.03291896]
#  [ 11.76640524]
#  [ -1.20102394]
#  [  4.39141801]
#  [  4.80762399]
#  [ -2.44743656]
#  [ -1.68422803]
#  [ -3.78927747]
#  [  2.15768621]
#  [ -2.51586451]
#  [ -0.53035624]
#  [  0.06581308]
#  [ -3.88858643]
#  [-10.09812759]
#  [  2.90901717]
#  [ -5.12934413]
#  [  9.02291229]
#  [  0.74716515]
#  [ -7.58150833]]
# -458.8181314894405 -523.2787649747212
